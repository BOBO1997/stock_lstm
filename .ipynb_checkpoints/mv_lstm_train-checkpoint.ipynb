# %% [markdown]
# # 多変量LSTM: モデルの訓練
#
# ### 使用するデータ
# - S&P500
# - アメリカ国債
# - 日経平均
#
#  #### 長続きして、なおかつある程度安定しているデータがいい？
#  - 日経平均はアメリカとあんまり関係ないし、戦後からバブルにかけて差が大きすぎる？
#  - 為替相場は歴史が浅い
#  - アメリカ国内失業率は月ごとのデータなので使い方がわからない
#  - ロンドンと香港とかがあればもっと良さそう
#
# ### 利点と展望
# - 経済の専門的な知識を必要としない
# - 使用するデータの種類(feature_vector)が多ければ多いほど、人間が気づかない予兆や規則を検出してくれるかもしれない
# - 予測に役立つ
#
# ### 今後に向けて
# - Attention、Transformerなど、いろいろな機能を追加/変更していければ
# - このフレームワークを使って、昔の似たようなパターンを見つけてくるタスクに関してはやり方がわかっていない

# %%
import sys
import inspect
import importlib
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import animation

import torch
import torch.nn as nn
import torch.utils.data as data
import torch.nn.functional as F
import torch.optim as optim

from mv_lstm_preprocess import mv_dataset
import mv_lstm_model
importlib.reload(mv_lstm_model)
from mv_lstm_model import mv_lstm, mv_lstm_same_seq

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
torch.manual_seed(1)
print(device)
# Out:
# cpu

# %% [markdown]
# ### parameters

# %%
seq_len = 50
predict_len = seq_len
predict_features = [0,1]
batch_size = 50
dropout = 0.2

epochs_num = 50
eps = 0.01
hidden_size = 20
num_layers = 2
input_size = None # 後から
output_size = len(predict_features)

# %%
file_paths = ["data/market_data_rm_inflation.csv", "data/nikkei_data.csv", "data/jgbcm_9.csv"]
dataset = mv_dataset(file_paths, seq_len=seq_len, predict_len=predict_len, predict_data=predict_features)

train_size = int(len(dataset) * 0.8)
test_size = len(dataset) - train_size
train_dataset, test_dataset = data.random_split(dataset, [train_size, test_size])

train_dataloader = data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True, drop_last=True)
test_dataloader = data.DataLoader(train_dataset, batch_size=1, shuffle=True, drop_last=True)

# %%
print(len(train_dataset))
print(len(test_dataset))
# Out:
# 8343
# 2086

# %%
input_size = dataset.dfs.shape[1]

model = mv_lstm_same_seq(input_size, 
                            output_size,
                            hidden_size=hidden_size, 
                            num_layers = num_layers, 
                            batch_size = batch_size, 
                            seq_len = seq_len, 
                            predict_len = predict_len,
                            dropout = dropout)
criterion = nn.MSELoss()
optimizer = optim.RMSprop(model.parameters())

train_ls, test_ls = [], []
train_as, test_as = [], []

# %% [markdown]
# ## 訓練
# - ist clusterのGPUの使い方がわかりません
# - 少なくともtest_accuracyの値のスケールは正しくないです
# - cpuだととても遅いです...( hours), 20:40~

# %%
for epoch in range(epochs_num):
    
    train_loss = 0.0
    train_accurate_num = 0
    for i, (batch_seqs, batch_labels) in enumerate(train_dataloader):
        optimizer.zero_grad()
        output = model(batch_seqs)
        loss = criterion(output, batch_labels).to(torch.float32)
        loss.backward()
        optimizer.step()
        train_loss += loss.data
        train_accurate_num += np.sum(np.abs((output.data - batch_labels).numpy()) < eps)

    train_accuracy = train_accurate_num / (train_size * predict_len * output_size)
    
    test_loss = 0.0
    test_accurate_num = 0
    for i, (batch_seqs, batch_labels) in enumerate(test_dataloader):
        output = model(batch_seqs)
        loss = criterion(output, batch_labels).to(torch.float32)
        test_loss += loss.data
        test_accurate_num += np.sum(np.abs((output.data - batch_labels).numpy()) < eps)

    test_accuracy = test_accurate_num / (test_size * predict_len * output_size)

    train_ls.append(train_loss)
    train_as.append(train_accuracy)
    test_ls.append(test_loss)
    test_as.append(test_accuracy)

    print("%d train_loss: %.3f, train_accuracy: %.5f, test_loss: %.3f, test_accuracy: %.5f" %(epoch + 1, train_loss, train_accuracy, test_loss, test_accuracy))
# Out:
# 1 training_loss: 15.696, training_accuracy: 0.05306, test_loss: 222.780, test_accyracy: 0.30423
# 2 training_loss: 4.878, training_accuracy: 0.07118, test_loss: 218.944, test_accyracy: 0.29208
# 3 training_loss: 4.202, training_accuracy: 0.07461, test_loss: 211.911, test_accyracy: 0.31483
# 4 training_loss: 3.831, training_accuracy: 0.08015, test_loss: 157.995, test_accyracy: 0.37689
# 5 training_loss: 3.528, training_accuracy: 0.08739, test_loss: 195.647, test_accyracy: 0.39176
# 6 training_loss: 3.446, training_accuracy: 0.09094, test_loss: 137.471, test_accyracy: 0.43423
# 7 training_loss: 3.307, training_accuracy: 0.09490, test_loss: 159.696, test_accyracy: 0.40311
# 8 training_loss: 2.976, training_accuracy: 0.10598, test_loss: 146.070, test_accyracy: 0.45251
# 9 training_loss: 2.886, training_accuracy: 0.10693, test_loss: 131.794, test_accyracy: 0.49812
# 10 training_loss: 2.775, training_accuracy: 0.10894, test_loss: 148.343, test_accyracy: 0.37580
# 11 training_loss: 2.841, training_accuracy: 0.10759, test_loss: 127.049, test_accyracy: 0.37778
# 12 training_loss: 2.583, training_accuracy: 0.11116, test_loss: 125.398, test_accyracy: 0.48883
# 13 training_loss: 2.576, training_accuracy: 0.11517, test_loss: 122.817, test_accyracy: 0.50356
# 14 training_loss: 2.493, training_accuracy: 0.11814, test_loss: 105.110, test_accyracy: 0.55780
# 15 training_loss: 2.475, training_accuracy: 0.11618, test_loss: 194.639, test_accyracy: 0.45029
# 16 training_loss: 2.335, training_accuracy: 0.12166, test_loss: 120.621, test_accyracy: 0.31524
# 17 training_loss: 2.318, training_accuracy: 0.11990, test_loss: 145.692, test_accyracy: 0.44934
# 18 training_loss: 2.329, training_accuracy: 0.12398, test_loss: 116.623, test_accyracy: 0.53025
# 19 training_loss: 2.221, training_accuracy: 0.12364, test_loss: 104.468, test_accyracy: 0.56257
# 20 training_loss: 2.220, training_accuracy: 0.12790, test_loss: 105.558, test_accyracy: 0.49648
# 21 training_loss: 2.247, training_accuracy: 0.12435, test_loss: 106.189, test_accyracy: 0.60030
# 22 training_loss: 2.140, training_accuracy: 0.12677, test_loss: 101.707, test_accyracy: 0.54675
# 23 training_loss: 2.082, training_accuracy: 0.12918, test_loss: 103.347, test_accyracy: 0.49985
# 24 training_loss: 2.037, training_accuracy: 0.12987, test_loss: 87.523, test_accyracy: 0.59770
# 25 training_loss: 2.073, training_accuracy: 0.12985, test_loss: 105.247, test_accyracy: 0.53535
# 26 training_loss: 1.941, training_accuracy: 0.13041, test_loss: 93.139, test_accyracy: 0.37593
# 27 training_loss: 2.054, training_accuracy: 0.12742, test_loss: 115.101, test_accyracy: 0.53593
# 28 training_loss: 1.994, training_accuracy: 0.13302, test_loss: 113.234, test_accyracy: 0.46058
# 29 training_loss: 1.916, training_accuracy: 0.13398, test_loss: 93.428, test_accyracy: 0.48640
# 30 training_loss: 1.981, training_accuracy: 0.13551, test_loss: 91.842, test_accyracy: 0.58264

# %%
model_name = "mv_lstm_same_seq"
using_data = "_data_usgd_ussp_nikkei_jgbcm"
torch.save(model.state_dict(), model_name + ".pth")

# %%
condition = model_name + using_data  + "_with_seq" + str(seq_len) + "_pred" + str(predict_len) +  "_ep" + str(epochs_num) + "_batch" + str(batch_size)+ "_hs" + str(hidden_size) + "_eps" + str(eps)
print(condition)
# Out:
# mv_lstm_same_seq_data_usgd_ussp_nikkei_jgbcm_with_seq50_pred50_ep30_batch50_hs20_eps0.01

# %%
def plot_results(result, which_result, condition, save_or_not=True):
    plt.clf()
    plt.plot(result)
    plt.title(condition + "_" + which_result)
    plt.savefig(condition + "_" + which_result + ".png") if save_or_not else plt.show()

# %%
plot_results(train_ls, "train_loss", condition)

# %%
plot_results(train_as, "train_accuracy", condition)

# %%
plot_results(test_ls, "test_loss", condition)

# %%
plot_results(test_as, "test_accuracy", condition)

# %%
import subprocess
subprocess.run(['jupyter', 'nbconvert', '--to', 'python', 'mv_lstm_train.ipynb'])
# Out:
# CompletedProcess(args=['jupyter', 'nbconvert', '--to', 'python', 'mv_lstm_train.ipynb'], returncode=0)

# %% [markdown]
# ### Accuracy が1を超えるのはなぜ？
